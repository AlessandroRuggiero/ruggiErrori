# %%
import ruggiErrori as r
import pandas as pd

# %%
df = pd.read_csv("../data/dati.csv")
df2 = pd.read_csv("../data/datiVel.csv")

# %%
f = r.grafici.grafico_scatole_spezzato(
    df,'Campione','secondi (s)',
    ybrake = 150, ystart = 750,
    ratio = [1,1],title = 'Tempo misurato' 
)

# %%
f = r.grafici.grafico_scatole_spezzato(
    df2,'Campione','velocità (moli/l*s)',
    ybrake = 0.0008, ystart = 0.00258,
    ratio = [1,8],title = 'Velocità di reazione' ,
    put_double_ylbl = False,labelsize = 15
)
